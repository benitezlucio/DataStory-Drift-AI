# %% [markdown]
# <a href="https://colab.research.google.com/github/benitezlucio/DataStory-Drift-AI/blob/main/DataStory_Drift_AI_POC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DataStory & Drift AI Engine — POC de Fast Prompting
#
# **Estudiante:** Lucio Benitez
# **Curso:** Generación de Prompts
# **Comisión:** `96090`
# **Entrega:** Entrega Final
#
# ## Objetivo de la notebook
# Demostrar cómo una combinación de validaciones en Python y Fast Prompting puede traducir señales de Model Drift y XAI a lenguaje ejecutivo, minimizando alucinaciones, exposición de datos sensibles y consultas innecesarias a una API.

# %% [markdown]
# ## 1. Diseño de la POC
#
# Flujo propuesto:
#
# **Métricas agregadas → validación Python → cálculo determinístico → prompt → LLM → validación de salida → revisión humana**
#
# Principios:
# - Python resuelve cálculos exactos.
# - El LLM no puede inventar métricas ni valores financieros.
# - SHAP se trata como explicación del comportamiento del modelo, no como causalidad.
# - Los datos son sintéticos y agregados.
# - El experimento A/B usa 2 llamadas; el flujo final usa 1 llamada por caso.

# %%
# Si es necesario, descomentar en un entorno nuevo:
# %pip install -q openai pandas

import os
import re
import json
from getpass import getpass

import pandas as pd

# %% [markdown]
# ## 2. Caso sintético de prueba
#
# Los datos de negocio son **sintéticos** y existen únicamente para demostrar la POC.
# No deben interpretarse como información de una empresa real.

# %%
case = {
    "model": "Predicción de churn de clientes bancarios",
    "period": "últimos 2 meses",
    "psi_before": 0.08,
    "psi_after": 0.28,
    "accuracy_drop_pct": 14.0,
    "changed_shap_factors": [
        "Frecuencia de transacciones internacionales",
        "Ratio de inflación percibida"
    ],
    "business_effect": "Aumento de falsos negativos en clientes VIP",

    # Variables sintéticas para estimar exposición económica.
    "vip_clients_at_risk": 120,
    "avg_monthly_margin_usd": 350,
    "retraining_cost_usd": 1800,

    "data_origin": "sintético / demostración académica"
}

case
# Out:
# {'model': 'Predicción de churn de clientes bancarios',
#  'period': 'últimos 2 meses',
#  'psi_before': 0.08,
#  'psi_after': 0.28,
#  'accuracy_drop_pct': 14.0,
#  'changed_shap_factors': ['Frecuencia de transacciones internacionales',
#   'Ratio de inflación percibida'],
#  'business_effect': 'Aumento de falsos negativos en clientes VIP',
#  'vip_clients_at_risk': 120,
#  'avg_monthly_margin_usd': 350,
#  'retraining_cost_usd': 1800,
#  'data_origin': 'sintético / demostración académica'}

# %% [markdown]
# ## 3. Controles de entrada
#
# Se bloquean identificadores personales y se validan rangos antes de enviar contenido al LLM.

# %%
SENSITIVE_KEYS = {
    "name", "nombre", "email", "dni", "documento",
    "account_number", "numero_cuenta", "client_id", "customer_id",
    "phone", "telefono", "address", "direccion"
}

def validate_no_sensitive_fields(data):
    suspicious = [k for k in data.keys() if k.lower() in SENSITIVE_KEYS]
    if suspicious:
        raise ValueError(
            f"Se detectaron campos potencialmente sensibles: {suspicious}. "
            "La POC solo admite datos agregados o sintéticos."
        )

def validate_metrics(data):
    required = [
        "psi_before", "psi_after", "accuracy_drop_pct",
        "changed_shap_factors", "business_effect"
    ]
    missing = [k for k in required if k not in data]
    if missing:
        raise ValueError(f"Faltan campos obligatorios: {missing}")

    if data["psi_before"] < 0 or data["psi_after"] < 0:
        raise ValueError("PSI no puede ser negativo.")

    if not 0 <= data["accuracy_drop_pct"] <= 100:
        raise ValueError("accuracy_drop_pct debe estar entre 0 y 100.")

    if not isinstance(data["changed_shap_factors"], list):
        raise TypeError("changed_shap_factors debe ser una lista.")

validate_no_sensitive_fields(case)
validate_metrics(case)
print("Entrada validada correctamente.")
# Out:
# Entrada validada correctamente.

# %% [markdown]
# ## 4. Cálculos determinísticos
#
# Para evitar alucinaciones aritméticas, los valores financieros se calculan en Python y se entregan ya resueltos al modelo.
#
# **Importante:** esta estimación representa una exposición teórica basada en las variables sintéticas cargadas. No supone que todos los clientes en riesgo vayan a abandonar.

# %%
business_metrics = {
    "maximum_monthly_margin_exposure_usd": (
        case["vip_clients_at_risk"] * case["avg_monthly_margin_usd"]
    ),
    "retraining_cost_usd": case["retraining_cost_usd"]
}

business_metrics
# Out:
# {'maximum_monthly_margin_exposure_usd': 42000, 'retraining_cost_usd': 1800}

# %% [markdown]
# ## 5. Clasificación orientativa de PSI
#
# Para la POC se define una política interna simplificada:
# - `< 0.10`: cambio bajo;
# - `0.10–0.25`: cambio moderado;
# - `> 0.25`: cambio alto.
#
# Estos umbrales se usan únicamente como regla de demostración y deben ser ajustados por el equipo responsable según el dominio y la política de monitoreo real.

# %%
def psi_status(value):
    if value < 0.10:
        return "bajo"
    if value <= 0.25:
        return "moderado"
    return "alto"

psi_analysis = {
    "before": psi_status(case["psi_before"]),
    "after": psi_status(case["psi_after"]),
    "delta": round(case["psi_after"] - case["psi_before"], 3)
}

psi_analysis
# Out:
# {'before': 'bajo', 'after': 'alto', 'delta': 0.2}

# %% [markdown]
# ## 6. Prompt A — Baseline
#
# Este prompt conserva la lógica general de la primera entrega. Sirve como punto de comparación.

# %%
def build_baseline_prompt(case, business_metrics):
    return f"""
Actúa como un Lead Data Scientist y Strategy Consultant.
Explica al comité ejecutivo el siguiente deterioro de modelo:

Modelo: {case['model']}
PSI: {case['psi_before']} -> {case['psi_after']}
Caída de precisión: {case['accuracy_drop_pct']}%
Factores SHAP que cambiaron: {", ".join(case['changed_shap_factors'])}
Impacto observado: {case['business_effect']}
Exposición máxima mensual calculada: USD {business_metrics['maximum_monthly_margin_exposure_usd']}
Costo de reentrenamiento: USD {business_metrics['retraining_cost_usd']}

Entrega:
1. Resumen ejecutivo.
2. Analogía para explicar el drift.
3. Impacto de negocio.
4. Plan de acción y ROI.
""".strip()

prompt_a = build_baseline_prompt(case, business_metrics)
print(prompt_a)
# Out:
# Actúa como un Lead Data Scientist y Strategy Consultant.
# Explica al comité ejecutivo el siguiente deterioro de modelo:
#
# Modelo: Predicción de churn de clientes bancarios
# PSI: 0.08 -> 0.28
# Caída de precisión: 14.0%
# Factores SHAP que cambiaron: Frecuencia de transacciones internacionales, Ratio de inflación percibida
# Impacto observado: Aumento de falsos negativos en clientes VIP
# Exposición máxima mensual calculada: USD 42000
# Costo de reentrenamiento: USD 1800
#
# Entrega:
# 1. Resumen ejecutivo.
# 2. Analogía para explicar el drift.
# 3. Impacto de negocio.
# 4. Plan de acción y ROI.

# %% [markdown]
# ## 7. Prompt B — Fast Prompting optimizado
#
# Mejoras incorporadas:
# - rol claro;
# - contexto delimitado;
# - grounding;
# - reglas contra causalidad indebida;
# - few-shot;
# - descomposición de tareas;
# - formato JSON;
# - auto-chequeo dentro de la misma consulta;
# - prompts visuales en la misma salida.

# %%
FEW_SHOT = """
EJEMPLO DE TRADUCCIÓN:
Señal técnica: "Una variable aumentó su importancia SHAP".
Traducción correcta: "El modelo está apoyándose más en esa señal para producir sus predicciones."
Traducción incorrecta: "Esa variable causó el comportamiento del cliente."
"""

def build_optimized_prompt(case, business_metrics, psi_analysis):
    payload = {
        "caso": case,
        "metricas_negocio_calculadas_por_python": business_metrics,
        "politica_psi_poc": psi_analysis
    }

    return f"""
[ROL]
Actúa como Lead Data Scientist & Strategy Consultant especializado en
AI Governance y Executive Data Storytelling.

[OBJETIVO]
Transformar métricas técnicas ya validadas en un memo ejecutivo breve
y en dos prompts visuales conceptuales.

[DATOS AUTORIZADOS]
--- INICIO DATOS ---
{json.dumps(payload, ensure_ascii=False, indent=2)}
--- FIN DATOS ---

[REGLAS DE GROUNDING]
1. Usa únicamente la información dentro de DATOS AUTORIZADOS.
2. No inventes métricas, porcentajes, causas, fechas, clientes ni importes.
3. Si un dato no está disponible, escribe exactamente: "NO DISPONIBLE".
4. No presentes SHAP como causalidad. SHAP describe contribución/importancia
   dentro del modelo, no una relación causal con el comportamiento real.
5. No conviertas una caída de precisión en una pérdida monetaria directa.
6. La "maximum_monthly_margin_exposure_usd" es exposición máxima teórica,
   no pérdida confirmada.
7. No incluyas datos personales ni solicites identificadores.
8. Toda recomendación requiere validación humana antes de una decisión real.

{FEW_SHOT}

[TAREAS]
A. Resume qué cambió y por qué merece atención ejecutiva.
B. Crea una analogía del mundo real para explicar Model Drift sin usar fórmulas.
C. Explica el impacto observado y separa claramente:
   - hechos medidos;
   - estimaciones;
   - limitaciones.
D. Propón máximo 3 acciones.
E. Genera un prompt visual conceptual para Model Drift.
F. Genera un prompt visual conceptual para XAI.

[RESTRICCIONES VISUALES]
- No pedir números, ejes, dashboards ni gráficos cuantitativos inventados.
- Evitar texto pequeño o ilegible.
- Model Drift: mostrar "distribución estable -> desplazamiento".
- XAI: mostrar "señal del modelo -> capa de explicación -> decisión humana".
- Estética profesional, ejecutiva, limpia, 16:9.

[AUTO-CHEQUEO INTERNO]
Antes de responder verifica:
- ¿Todos los números provienen de los datos?
- ¿Se evitó causalidad indebida?
- ¿Se distinguieron hechos y estimaciones?
- ¿Se indicó revisión humana?
- ¿Los prompts visuales son conceptuales y no aparentan evidencia cuantitativa?
No muestres este razonamiento; devuelve solamente el resultado final.

[FORMATO DE SALIDA]
Devuelve SOLO JSON válido con esta estructura:
{{
  "status_validacion": "APTO o REVISAR",
  "resumen_ejecutivo": "...",
  "analogia_negocio": "...",
  "impacto": {{
    "hechos_medidos": ["..."],
    "estimaciones": ["..."],
    "limitaciones": ["..."]
  }},
  "plan_accion": ["...", "...", "..."],
  "prompt_imagen_model_drift": "...",
  "prompt_imagen_xai": "...",
  "requiere_revision_humana": true
}}
""".strip()

prompt_b = build_optimized_prompt(case, business_metrics, psi_analysis)
print(prompt_b)
# Out:
# [ROL]
# Actúa como Lead Data Scientist & Strategy Consultant especializado en
# AI Governance y Executive Data Storytelling.
#
# [OBJETIVO]
# Transformar métricas técnicas ya validadas en un memo ejecutivo breve
# y en dos prompts visuales conceptuales.
#
# [DATOS AUTORIZADOS]
# --- INICIO DATOS ---
# {
#   "caso": {
#     "model": "Predicción de churn de clientes bancarios",
#     "period": "últimos 2 meses",
#     "psi_before": 0.08,
#     "psi_after": 0.28,
#     "accuracy_drop_pct": 14.0,
#     "changed_shap_factors": [
#       "Frecuencia de transacciones internacionales",
#       "Ratio de inflación percibida"
#     ],
#     "business_effect": "Aumento de falsos negativos en clientes VIP",
#     "vip_clients_at_risk": 120,
#     "avg_monthly_margin_usd": 350,
#     "retraining_cost_usd": 1800,
#     "data_origin": "sintético / demostración académica"
#   },
#   "metricas_negocio_calculadas_por_python": {
#     "maximum_monthly_margin_exposure_usd": 42000,
#     "retraining_cost_usd": 1800
#   },
#   "politica_psi_poc": {
#     "before": "bajo",
#     "after": "alto",
#     "delta": 0.2
#   }
# }
# --- FIN DATOS ---
#
# [REGLAS DE GROUNDING]
# 1. Usa únicamente la información dentro de DATOS AUTORIZADOS.
# 2. No inventes métricas, porcentajes, causas, fechas, clientes ni importes.
# 3. Si un dato no está disponible, escribe exactamente: "NO DISPONIBLE".
# 4. No presentes SHAP como causalidad. SHAP describe contribución/importancia
#    dentro del modelo, no una relación causal con el comportamiento real.
# 5. No conviertas una caída de precisión en una pérdida monetaria directa.
# 6. La "maximum_monthly_margin_exposure_usd" es exposición máxima teórica,
#    no pérdida confirmada.
# 7. No incluyas datos personales ni solicites identificadores.
# 8. Toda recomendación requiere validación humana antes de una decisión real.
#
#
# EJEMPLO DE TRADUCCIÓN:
# Señal técnica: "Una variable aumentó su importancia SHAP".
# Traducción correcta: "El modelo está apoyándose más en esa señal para producir sus predicciones."
# Traducción incorrecta: "Esa variable causó el comportamiento del cliente."
#
#
# [TAREAS]
# A. Resume qué cambió y por qué merece atención ejecutiva.
# B. Crea una analogía del mundo real para explicar Model Drift sin usar fórmulas.
# C. Explica el impacto observado y separa claramente:
#    - hechos medidos;
#    - estimaciones;
#    - limitaciones.
# D. Propón máximo 3 acciones.
# E. Genera un prompt visual conceptual para Model Drift.
# F. Genera un prompt visual conceptual para XAI.
#
# [RESTRICCIONES VISUALES]
# - No pedir números, ejes, dashboards ni gráficos cuantitativos inventados.
# - Evitar texto pequeño o ilegible.
# - Model Drift: mostrar "distribución estable -> desplazamiento".
# - XAI: mostrar "señal del modelo -> capa de explicación -> decisión humana".
# - Estética profesional, ejecutiva, limpia, 16:9.
#
# [AUTO-CHEQUEO INTERNO]
# Antes de responder verifica:
# - ¿Todos los números provienen de los datos?
# - ¿Se evitó causalidad indebida?
# - ¿Se distinguieron hechos y estimaciones?
# - ¿Se indicó revisión humana?
# - ¿Los prompts visuales son conceptuales y no aparentan evidencia cuantitativa?
# No muestres este razonamiento; devuelve solamente el resultado final.
#
# [FORMATO DE SALIDA]
# Devuelve SOLO JSON válido con esta estructura:
# {
#   "status_validacion": "APTO o REVISAR",
#   "resumen_ejecutivo": "...",
#   "analogia_negocio": "...",
#   "impacto": {
#     "hechos_medidos": ["..."],
#     "estimaciones": ["..."],
#     "limitaciones": ["..."]
#   },
#   "plan_accion": ["...", "...", "..."],
#   "prompt_imagen_model_drift": "...",
#   "prompt_imagen_xai": "...",
#   "requiere_revision_humana": true
# }

# %% [markdown]
# ## 8. Configuración opcional de la API
#
# La clave **no se escribe en la notebook**. Se solicita de forma interactiva.
#
# Para revisar la estructura sin gastar API, mantener `RUN_API = False`.
# Para ejecutar la demostración real, cambiarlo a `True`.
#
# > La Responses API permite recuperar el uso de tokens de la respuesta, lo que facilita registrar el costo técnico de cada experimento.

# %%
RUN_API = True
MODEL = "openrouter/free"

api_calls = 0
usage_log = []

if RUN_API:
    from openai import OpenAI

    if not os.getenv("OPENROUTER_API_KEY"):
        os.environ["OPENROUTER_API_KEY"] = getpass("OPENROUTER_API_KEY: ")

    client = OpenAI(
        base_url="https://openrouter.ai/api/v1",
        api_key=os.environ["OPENROUTER_API_KEY"]
    )
else:
    client = None

print("Modo:", "API REAL" if RUN_API else "DRY RUN")
print("Modelo:", MODEL)
# Out:
# OPENROUTER_API_KEY: ··········
# Modo: API REAL
# Modelo: openrouter/free

# %%
def call_llm(prompt, label):
    global api_calls

    if not RUN_API:
        print(f"[DRY RUN] {label}: no se realizó ninguna consulta.")
        return None

    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {
                "role": "user",
                "content": prompt
            }
        ]
    )

    api_calls += 1

    usage = {
        "label": label,
        "model": getattr(response, "model", MODEL),
        "input_tokens": getattr(response.usage, "prompt_tokens", None),
        "output_tokens": getattr(response.usage, "completion_tokens", None),
        "total_tokens": getattr(response.usage, "total_tokens", None),
    }

    usage_log.append(usage)

    return response.choices[0].message.content

# %%
test_response = call_llm(
    "Responde únicamente con: API funcionando correctamente",
    "connection_test"
)

print(test_response)
# Out:
# API funcionando correctamente

# %%
api_calls = 0
usage_log = []

print("Métricas reiniciadas para el experimento A/B.")
# Out:
# Métricas reiniciadas para el experimento A/B.

# %% [markdown]
# ## 9. Experimento A/B
#
# Durante el experimento se realizan como máximo **2 consultas**:
# 1. Prompt A — baseline.
# 2. Prompt B — optimizado.
#
# En operación real se conserva únicamente Prompt B, por lo que el costo baja a **1 consulta por caso**.

# %%
output_a = call_llm(prompt_a, "baseline")
output_b = call_llm(prompt_b, "optimized")

print("Consultas realizadas:", api_calls)
# Out:
# Consultas realizadas: 2

# %%
print("=" * 80)
print("PROMPT A — BASELINE")
print("=" * 80)
print(output_a)

print("\n" + "=" * 80)
print("PROMPT B — FAST PROMPTING OPTIMIZADO")
print("=" * 80)
print(output_b)
# Out:
# ================================================================================
# PROMPT A — BASELINE
# ================================================================================
# **1. Resumen ejecutivo**
#
# - **Deterioro del modelo**: El indicador de *Population Stability Index* (PSI) se ha disparado de **0.08 → 0.28**, lo que señala un **cambio estructural importante** en la distribución de los inputs del modelo.
# - **Precisión**: La exactitud (accuracy) cayó **14 %** (p. ej., de 86 % a 72 %).
# - **Factores SHAP que ahora dominan**:
#   - *Frecuencia de transacciones internacionales* (antes bajo impacto).
#   - *Ratio de inflación percibida* (nuevo predictor fuerte).
# - **Consecuencia operativa**: **Falsos negativos** en clientes **VIP** aumentan, lo que implica que los clientes de mayor valor están abandonando sin ser detectados.
# - **Exposición financiera**: **USD 42 000** de pérdida potencial mensual por churn no detectado.
# - **Costo de re‑entrenamiento**: **USD 1 800** (≈ 0.4 % de la exposición mensual).
#
# **Conclusión**: El modelo ya no captura la realidad actual de los clientes; la deriva es suficientemente grande como para requerir una acción inmediata, pero el coste de corregirla es bajo y la ganancia esperada alta.
#
# ---
#
# **2. Analogía para explicar el *drift***
#
# > **Imagina que tu modelo es un GPS que, hasta ahora, te guiaba por una autopista bien señalizada (las condiciones de la carretera y el tráfico eran estables). De repente, el gobierno cambia el sentido del tráfico, cierra varios carriles y introduce una nueva tarifa de peaje. El GPS sigue usando la misma ruta y los mismos puntos de referencia, por lo que empieza a enviarte por caminos equivocados, retrasándote y, en algunos casos, llevándote a un desvío peligroso.**
#
# En nuestro caso, los “carriles” (variables) y la “señal de tráfico” (relación entre variables y churn) cambiaron por factores macroeconómicos (inflación, tipo de cambio) y conductuales (incremento de compras internacionales). El modelo, sin actualizarse, sigue usando la “ruta antigua” y empieza a perder a los clientes más valiosos (VIP).
#
# ---
#
# **3. Impacto de negocio**
#
# | Aspecto | Detalle | Consecuencia |
# |--------|---------|--------------|
# | **Pérdida de ingresos** | Falsos negativos en VIP → clientes de alto valor se van sin que lo detectemos. | Reducción directa de revenue‑stream y mayor coste de adquisición para reemplazarlos. |
# | **Exposición financiera** | USD 42 000/mes de churn no anticipado. | Impacta el EBITDA y el ratio de retención de clientes (NPS). |
# | **Riesgo reputacional** | Clientes VIP son embajadores de la marca; su abandono puede generar efectos de contagio negativos. | Posible deterioro de la percepción de la banca y mayor presión regulatoria. |
# | **Coste de corrección** | Re‑entrenamiento: USD 1 800 (≈ 0.4 % de la exposición mensual). | Inversión mínima comparada con la pérdida potencial. |
# | **Beneficio esperado** | Mejora de precisión ≈ 14 % → reducción de falsos negativos en ~30 % (estimado). | Recuperación de una parte significativa de la exposición (≈ USD 12‑15 k/mes). |
#
# En síntesis, la deriva está costando **~USD 42 k/mes** mientras la solución cuesta **~USD 1.8 k**, lo que genera un **ROI potencial de > 2 000 %** en el primer año de operación.
#
# ---
#
# **4. Plan de acción y ROI**
#
# | Paso | Acción | Responsable | Tiempo estimado | Comentario |
# |------|--------|-------------|----------------|------------|
# | **1. Auditoría de datos** | Revisar la procedencia y calidad de *frecuencia de transacciones internacionales* y *ratio de inflación percibida* (fuentes, timestamps, cambios de esquema). | Data Engineering | 1 semana | Detectar posibles “cambios de contrato” o nuevas fuentes de datos. |
# | **2. Actualización del feature‑engineering** | - Normalizar/ponderar la nueva distribución de la frecuencia internacional.<br>- Incorporar indicadores de inflación (IPC, tipo de cambio) y de expectativas del cliente (encuestas, sentimiento). | Data Science | 2 semanas | Amplía la capacidad del modelo para capturar el nuevo contexto. |
# | **3. Re‑entrenamiento del modelo** | - Split de datos actualizado (últimos 6‑12 meses).<br>- Entrenamiento con validación cruzada y monitoreo de PSI en tiempo real. | Data Science | 1 semana (más 1 día de validación) | Coste USD 1 800 (CPU/GPU en la nube). |
# | **4. Validación y ajuste de umbral** | - Analizar la curva ROC y seleccionar un umbral que minimice falsos negativos en VIP. | Data Science + Risk | 3‑4 días | Prioriza recall en segmento VIP (> 90 %). |
# | **5. Implementación en producción** | - Despliegue gradual (shadow mode) 2 semanas.<br>- Monitoreo de PSI, precisión y exposición mensual. | MLOps | 2 semanas | Permite detectar retro‑desplazamientos rápidamente. |
# | **6. Governance y reporte** | - Definir SLA de detección de drift (PSI > 0.2).<br>- Reporte mensual al comité con KPIs: PSI, accuracy, exposición, ROI. | Lead Data Scientist | Ongoing | Garantiza que el modelo se mantenga estable. |
#
# ### Estimación de ROI
#
# - **Ahorro esperado**: Reducción del 30 % en falsos negativos VIP → recuperación de **USD 12‑15 k/mes** (≈ USD 144‑180 k/año).
# - **Costo total** (re‑entrenamiento + MLOps + personal): **≈ USD 5 k** (incluye tiempo de trabajo y licencias).
# - **Beneficio neto** (primer año): **≈ USD 140 k**.
# - **ROI** = (Beneficio – Costo) / Costo ≈ **(140 k – 5 k) / 5 k = 27 × 100 % → 2 700 %** (conservador).
#
# > **Conclusión**: La inversión es mínima y el retorno potencial es extremadamente alto, justificando la ejecución inmediata del plan.
#
# ---
#
# **Recomendación final al Comité:**
# Aprobad la puesta en marcha del plan de acción (≈ USD 5 k) para estabilizar el modelo, recuperar la pérdida de clientes VIP y proteger la rentabilidad de la banca. El ROI estimado (> 2 000 %) y la rapidez de implementación hacen esta iniciativa una prioridad estratégica.
#
# ================================================================================
# PROMPT B — FAST PROMPTING OPTIMIZADO
# ================================================================================
# {
#   "status_validacion": "APTO",
#   "resumen_ejecutivo": "En los últimos 2 meses el modelo de churn bancario pasó de un ψ bajo (0.08) a alto (0.28), con una caída del 14 % en precisión y cambios en los factores SHAP de frecuencia de transacciones internacionales y ratio de inflación percibida, lo que incrementó falsos negativos entre clientes VIP (120 en riesgo) y generó una exposición teórica máxima de margen de 42 000 USD mensuales, mientras el costo de retraining es de 1 800 USD.",
#   "analogia_negocio": "Como una brújula que pierde su alineación cuando el campo magnético cambia, el modelo de churn se vuelve menos preciso cuando la distribución de sus variables de entrada se desplaza.",
#   "impacto": {
#     "hechos_medidos": [
#       "ψ bajo 0.08 → ψ alto 0.28",
#       "Precisión caída 14 %",
#       "Factores SHAP: frecuencia de transacciones internacionales, ratio de inflación percibida",
#       "120 clientes VIP en riesgo",
#       "Margen mensual promedio 350 USD",
#       "Costo de retraining 1 800 USD",
#       "Exposición máxima de margen mensual 42 000 USD",
#       "Δ ψ = 0.2 (de bajo a alto)"
#     ],
#     "estimaciones": [
#       "Posible pérdida de margen por falsos negativos en clientes VIP",
#       "Estimación de exposición de margen basada en el máximo teórico disponible"
#     ],
#     "limitaciones": [
#       "Datos sintéticos de demostración académica, no reflejan entorno real",
#       "Periodo de evaluación limitado a 2 meses",
#       "SHAP muestra contribución del modelo, no relación causal con comportamiento del cliente",
#       "Umbral ψ no validado en contexto operativo",
#       "No se dispone de información sobre tasas reales de churn ni de ingresos reales"
#     ]
#   },
#   "plan_accion": [
#     "Realizar análisis de causa raíz con equipos de negocio para validar los desplazamientos detectados",
#     "Retraining del modelo con datos actualizados y re‑evaluar precisión y métricas de drift",
#     "Implementar monitorización continua de ψ y de los factores SHAP críticos con alertas para revisión ejecutiva"
#   ],
#   "prompt_imagen_model_drift": "Ilustración de dos distribuciones de probabilidad superpuestas: una estable (izquierda) y otra desplazada a la derecha (derecha), con una flecha que indica el desplazamiento, estilo limpio y profesional, sin ejes ni números.",
#   "prompt_imagen_xai": "Representación de una red neuronal que envía una señal a una capa de explicación que resalta la variable importante, seguida de una flecha hacia una figura humana que toma la decisión, estilo ejecutivo y minimalista.",
#   "requiere_revision_humana": true
# }

# %%
usage_df = pd.DataFrame(usage_log)

usage_df
# Out:
#        label                                              model  input_tokens  \
# 0   baseline  nvidia/nemotron-3-nano-omni-30b-a3b-reasoning:...           185
# 1  optimized  nvidia/nemotron-3-nano-omni-30b-a3b-reasoning:...          1028
#
#    output_tokens  total_tokens
# 0           1936          2121
# 1           2465          3493

# %%
models_used = usage_df["model"].unique()

print("Modelos utilizados:")
for model in models_used:
    print("-", model)

if len(models_used) == 1:
    print("\n✅ Prompt A y Prompt B fueron evaluados con el mismo modelo.")
else:
    print(
        "\n⚠️ OpenRouter utilizó modelos diferentes. "
        "Esto debe declararse como una limitación del experimento."
    )
# Out:
# Modelos utilizados:
# - nvidia/nemotron-3-nano-omni-30b-a3b-reasoning:free
#
# ✅ Prompt A y Prompt B fueron evaluados con el mismo modelo.

# %% [markdown]
# ## 10. Parseo y control de la salida optimizada

# %%
def parse_json_output(text):
    if text is None:
        return None
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        # Fallback básico si el modelo agrega fences markdown.
        cleaned = re.sub(r"^```json\s*|\s*```$", "", text.strip(), flags=re.IGNORECASE)
        return json.loads(cleaned)

def validate_optimized_output(result):
    if result is None:
        return {"status": "NO EJECUTADO", "issues": []}

    issues = []
    required = {
        "status_validacion",
        "resumen_ejecutivo",
        "analogia_negocio",
        "impacto",
        "plan_accion",
        "prompt_imagen_model_drift",
        "prompt_imagen_xai",
        "requiere_revision_humana"
    }

    missing = sorted(required - set(result.keys()))
    if missing:
        issues.append(f"Faltan campos: {missing}")

    if result.get("requiere_revision_humana") is not True:
        issues.append("Debe requerir revisión humana.")

    text = json.dumps(result, ensure_ascii=False).lower()

    # Control simple de causalidad indebida alrededor de SHAP.
    risky_phrases = [
        "shap demuestra que",
        "shap prueba que",
        "shap confirma que",
        "causado por shap"
    ]
    for phrase in risky_phrases:
        if phrase in text:
            issues.append(f"Posible causalidad indebida: '{phrase}'")

    return {
        "status": "APTO" if not issues else "REVISAR",
        "issues": issues
    }

parsed_b = parse_json_output(output_b)
validation_b = validate_optimized_output(parsed_b)
validation_b

# %% [markdown]
# ## 11. Comparación de configuraciones
#
# No se utiliza otro LLM como juez porque agregaría una tercera consulta.
# La evaluación combina criterios observables y revisión humana.

# %%
comparison = pd.DataFrame([
    {
        "criterio": "Rol y contexto delimitado",
        "Prompt A": "Parcial",
        "Prompt B": "Sí"
    },
    {
        "criterio": "Grounding explícito",
        "Prompt A": "No",
        "Prompt B": "Sí"
    },
    {
        "criterio": "Control de causalidad SHAP",
        "Prompt A": "No",
        "Prompt B": "Sí"
    },
    {
        "criterio": "Valores financieros calculados en Python",
        "Prompt A": "Sí",
        "Prompt B": "Sí"
    },
    {
        "criterio": "Formato estructurado",
        "Prompt A": "No",
        "Prompt B": "JSON"
    },
    {
        "criterio": "Self-check sin llamada extra",
        "Prompt A": "No",
        "Prompt B": "Sí"
    },
    {
        "criterio": "Prompts visuales incluidos",
        "Prompt A": "No",
        "Prompt B": "Sí"
    },
])

comparison

# %% [markdown]
# ### Rúbrica manual de eficacia
#
# Después de ejecutar ambos prompts, puntuar de 1 a 5:
# - claridad ejecutiva;
# - fidelidad a los datos;
# - ausencia de causalidad indebida;
# - accionabilidad;
# - concisión;
# - cumplimiento del formato.
#
# Registrar los resultados reales en la tabla siguiente.

# %%
rubric = pd.DataFrame({
    "criterio": [
        "Claridad ejecutiva",
        "Fidelidad a los datos",
        "Ausencia de causalidad indebida",
        "Accionabilidad",
        "Concisión",
        "Cumplimiento de formato"
    ],
    "Prompt A (1-5)": [4, 1, 1, 3, 2, 4],
    "Prompt B (1-5)": [5, 4, 5, 4, 5, 5]
})

rubric

# %%
print(
    "Promedio Prompt A:",
    round(rubric["Prompt A (1-5)"].mean(), 2)
)

print(
    "Promedio Prompt B:",
    round(rubric["Prompt B (1-5)"].mean(), 2)
)

# %% [markdown]
# ## 12. Registro de uso y costos
#
# La POC registra tokens y cantidad de consultas. Para un cálculo monetario exacto, multiplicar el uso por la tarifa vigente del modelo elegido al momento de ejecutar la notebook.
#
# Esto evita dejar un precio fijo que pueda quedar desactualizado.

# %%
usage_df = pd.DataFrame(usage_log)
usage_df

# %%
print(f"Total de consultas API ejecutadas: {api_calls}")
print("Objetivo en producción: 1 consulta por caso.")

# %% [markdown]
# ### Análisis del experimento
#
# El Prompt A obtuvo una respuesta visualmente clara y accionable, pero
# introdujo múltiples datos que no estaban presentes en el contexto original.
# Entre ellos se encontraron fechas, causas económicas, probabilidades de
# pérdida, proyecciones anuales, costos desglosados y métricas de ROI.
#
# El Prompt B redujo significativamente estos problemas mediante técnicas de
# Fast Prompting como grounding explícito, delimitación de contexto,
# few-shot prompting, descomposición de tareas, restricciones de salida y
# auto-validación.
#
# La puntuación promedio aumentó de **2.50/5 en el Prompt A a 4.67/5 en el
# Prompt B**.
#
# La validación automática clasificó la salida optimizada como `APTO`.
# Sin embargo, la revisión humana encontró dos pequeñas imprecisiones
# semánticas: el uso de "ingresos" en lugar de "margen" y la recomendación
# de "incorporar" variables cuando sería más correcto hablar de reevaluarlas.
#
# Este resultado refuerza la decisión de mantener una instancia de
# validación humana incluso después de aplicar controles automáticos.

# %% [markdown]
# ## 13. Iteración de prompts visuales
#
# ### Model Drift
# **V1:** estética futurista + dashboards + gráficos.
# **Riesgo:** números/ejes inventados y texto ilegible.
# **V2:** imagen conceptual 16:9, sin cifras ni gráficos cuantitativos, enfocada en el desplazamiento de una distribución.
#
# ### XAI
# **V1:** esfera con red neuronal.
# **Riesgo:** imagen atractiva pero genérica.
# **V2:** tres etapas visuales: señal del modelo → explicación → decisión humana; sin causalidad ni texto pequeño.
#
# Si `Prompt B` fue ejecutado, los prompts finales aparecen en:
# - `parsed_b["prompt_imagen_model_drift"]`
# - `parsed_b["prompt_imagen_xai"]`

# %%
if parsed_b:
    print("MODEL DRIFT:\n", parsed_b.get("prompt_imagen_model_drift"))
    print("\nXAI:\n", parsed_b.get("prompt_imagen_xai"))
else:
    print("Ejecutar Prompt B para obtener los prompts visuales finales.")

# %% [markdown]
# ## 14. Criterios de aprobación
#
# La POC se considera aprobada cuando:
# 1. la entrada no contiene datos sensibles;
# 2. las métricas pasan las validaciones;
# 3. el Prompt B devuelve la estructura requerida;
# 4. no inventa cifras;
# 5. no trata SHAP como causalidad;
# 6. diferencia hechos, estimaciones y limitaciones;
# 7. exige revisión humana;
# 8. el flujo final utiliza una sola consulta por caso.
#
# ---
#
# ## 15. Conclusión
#
# Fast Prompting mejora la propuesta inicial porque no se limita a agregar instrucciones: organiza el contexto, restringe el espacio de respuesta, incluye ejemplos, define un formato verificable y combina el LLM con controles determinísticos.
#
# La arquitectura resultante es más clara, reproducible, económica y segura para una POC de comunicación ejecutiva de Model Drift y XAI.
